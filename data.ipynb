# %%
print('shubham is a good boy')
# Out:
# shubham is a good boy

# %%
print("SHUBHAM IS AGOOD BOY")
# Out:
# SHUBHAM IS AGOOD BOY

# %%
x=10
y= 'hello'
print(x)
print(y)
# Out:
# 10
# hello

# %%
print(x,y)
# Out:
# 10 hello

# %%
#the value of x is = 10
print("the value of x and y is",x,y)
# Out:
# the value of x and y is 10 hello

# %%
# sign indicates a comment that is the non executable statment
print('the value of x is',x,'the value of y is',y)
# Out:
# the value of x is 10 the value of y is hello

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
z=10.5
print(type(z))
# Out:
# <class 'float'>

# %%
b=True
print(type(b))
# Out:
# <class 'bool'>

# %%
t=10,5
print(type(t))
# Out:
# <class 'tuple'>

# %%
print(t)
# Out:
# (10, 5)
